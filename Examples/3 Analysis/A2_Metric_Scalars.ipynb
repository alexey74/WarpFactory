% %% [markdown]
% ## Computing Metric Scalars
% ### Get Metric

% %%
%% Alcubierre
gridSize = [1 20 20 20];
worldCenter = (gridSize+1)./2;
velocity = 0.5;
R = 5;
sigma = 0.5;
Metric = metricGet_AlcubierreComoving(gridSize,worldCenter,velocity,R,sigma);

% %% [markdown]
% ### Get Scalars

% %%
[expansionScalar, shearScalar, vorticityScalar] = getScalars(Metric);

% %% [markdown]
% ### Plot Scalars

% %%
surfq(expansionScalar(1,:,:,10),'EdgeColor','none')
title('Expansion Scalar')
% Out:
% <center><img src="data:image/png;base64,..." width="154" alt="figure_0.png"></center>

% %%
surfq(shearScalar(1,:,:,10),'EdgeColor','none')
title('Shear Scalar')
% Out:
% <center><img src="data:image/png;base64,..." width="154" alt="figure_1.png"></center>

% %%
surfq(vorticityScalar(1,:,:,10),'EdgeColor','none')
title('Vorticity Scalar')
% Out:
% <center><img src="data:image/png;base64,..." width="154" alt="figure_2.png"></center>
