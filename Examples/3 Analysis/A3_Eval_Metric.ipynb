% %% [markdown]
% ## Eval Metric
%
% evalMetric computes:
%
% 1.  The energy tensor,
% 2. The eulerian energy tensor,
% 3. The null, weak, strong and dominant energy conditions,
% 4. The expansion, shear, and vorticity scalars,
%
% All in 1 line of code.

% %%
%% Make Metric
gridSize = [1 20 20 20];
worldCenter = (gridSize+1)./2;
velocity = 0.5;
R = 5;
sigma = 0.5;
Metric = metricGet_AlcubierreComoving(gridSize,worldCenter,velocity,R,sigma);

%% Run evalMetric
[Evaluation] = evalMetric(Metric);

% %% [markdown]
% Get field names

% %%
fieldnames(Evaluation)
% Out:
% ans = 10x1 cell
% 'metric'
% 'energyTensor'
% 'energyTensorEulerian'
% 'null'
% 'weak'
% 'strong'
% 'dominant'
% 'expansion'
% 'shear'
% 'vorticity'

% %% [markdown]
% ### Metric

% %%
plotTensor(Evaluation.metric, 0)
% Out:
% <center><img src="data:image/png;base64,..." width="562" alt="figure_0.png"></center>
% <center><img src="data:image/png;base64,..." width="562" alt="figure_1.png"></center>

% %% [markdown]
% <center><img src="data:image/png;base64,..." width="562" alt="figure_2.png"></center>
%
%
% <center><img src="data:image/png;base64,..." width="562" alt="figure_3.png"></center>
%
%
% <center><img src="data:image/png;base64,..." width="562" alt="figure_4.png"></center>
%
%
% <center><img src="data:image/png;base64,..." width="562" alt="figure_5.png"></center>
%
%
% <center><img src="data:image/png;base64,..." width="562" alt="figure_6.png"></center>
%
%
% <center><img src="data:image/png;base64,..." width="562" alt="figure_7.png"></center>
%
%
% <center><img src="data:image/png;base64,..." width="562" alt="figure_8.png"></center>
%
%
% <center><img src="data:image/png;base64,..." width="562" alt="figure_9.png"></center>
%
% ### Energy Tensor

% %%
plotTensor(Evaluation.energyTensor, 0)
% Out:
% <center><img src="data:image/png;base64,..." width="562" alt="figure_10.png"></center>
% <center><img src="data:image/png;base64,..." width="562" alt="figure_11.png"></center>

% %% [markdown]
% <center><img src="data:image/png;base64,..." width="562" alt="figure_12.png"></center>
%
%
% <center><img src="data:image/png;base64,..." width="562" alt="figure_13.png"></center>
%
%
% <center><img src="data:image/png;base64,..." width="562" alt="figure_14.png"></center>
%
%
% <center><img src="data:image/png;base64,..." width="562" alt="figure_15.png"></center>
%
%
% <center><img src="data:image/png;base64,..." width="562" alt="figure_16.png"></center>
%
%
% <center><img src="data:image/png;base64,..." width="562" alt="figure_17.png"></center>
%
%
% <center><img src="data:image/png;base64,..." width="562" alt="figure_18.png"></center>
%
%
% <center><img src="data:image/png;base64,..." width="562" alt="figure_19.png"></center>
%
% ### Eulerian Energy Tensor

% %%
plotTensor(Evaluation.energyTensorEulerian, 0)
% Out:
% <center><img src="data:image/png;base64,..." width="562" alt="figure_20.png"></center>
% <center><img src="data:image/png;base64,..." width="562" alt="figure_21.png"></center>

% %% [markdown]
% <center><img src="data:image/png;base64,..." width="562" alt="figure_22.png"></center>
%
%
% <center><img src="data:image/png;base64,..." width="562" alt="figure_23.png"></center>
%
%
% <center><img src="data:image/png;base64,..." width="562" alt="figure_24.png"></center>
%
%
% <center><img src="data:image/png;base64,..." width="562" alt="figure_25.png"></center>
%
%
% <center><img src="data:image/png;base64,..." width="562" alt="figure_26.png"></center>
%
%
% <center><img src="data:image/png;base64,..." width="562" alt="figure_27.png"></center>
%
%
% <center><img src="data:image/png;base64,..." width="562" alt="figure_28.png"></center>
%
%
% <center><img src="data:image/png;base64,..." width="562" alt="figure_29.png"></center>
%
% ### Null Energy Condition

% %%
surfq(Evaluation.null(1,3:end-2,3:end-2,round(worldCenter(4))))
title("Null")
view(2)
xlim([1 gridSize(2)-4])
ylim([1 gridSize(3)-4])
% Out:
% <center><img src="data:image/png;base64,..." width="562" alt="figure_30.png"></center>

% %% [markdown]
% ### Weak Energy Condition

% %%
surfq(Evaluation.weak(1,3:end-2,3:end-2,round(worldCenter(4))))
title("Weak")
view(2)
xlim([1 gridSize(2)-4])
ylim([1 gridSize(3)-4])
% Out:
% <center><img src="data:image/png;base64,..." width="562" alt="figure_31.png"></center>

% %% [markdown]
% ### Strong Energy Condition

% %%
surfq(Evaluation.strong(1,3:end-2,3:end-2,round(worldCenter(4))))
title("Strong")
view(2)
xlim([1 gridSize(2)-4])
ylim([1 gridSize(3)-4])
% Out:
% <center><img src="data:image/png;base64,..." width="562" alt="figure_32.png"></center>

% %% [markdown]
% ### Dominant Energy Condition

% %%
surfq(Evaluation.dominant(1,3:end-2,3:end-2,round(worldCenter(4))))
title("Dominant")
view(2)
xlim([1 gridSize(2)-4])
ylim([1 gridSize(3)-4])
% Out:
% <center><img src="data:image/png;base64,..." width="562" alt="figure_33.png"></center>

% %% [markdown]
% ### Expansion Scalar

% %%
surfq(Evaluation.expansion(1,:,:,round(worldCenter(4))))
title("Expansion Scalar")
view(2)
xlim([1 gridSize(2)])
ylim([1 gridSize(3)])
% Out:
% <center><img src="data:image/png;base64,..." width="562" alt="figure_34.png"></center>

% %% [markdown]
% ### Shear Scalar

% %%
surfq(Evaluation.shear(1,:,:,round(worldCenter(4))))
title("Shear Scalar")
view(2)
xlim([1 gridSize(2)])
ylim([1 gridSize(3)])
% Out:
% <center><img src="data:image/png;base64,..." width="562" alt="figure_35.png"></center>

% %% [markdown]
% ### Vorticity Scalar

% %%
surfq(Evaluation.vorticity(1,:,:,round(worldCenter(4))))
title("Vorticity Scalar")
view(2)
xlim([1 gridSize(2)])
ylim([1 gridSize(3)])
% Out:
% <center><img src="data:image/png;base64,..." width="562" alt="figure_36.png"></center>

% %% [markdown]
% Vorticity should always be 0.
